# %% [markdown]
# # 4) Evaluation & Ablation

# %% [markdown]
# Evaluate best model(s) on **test set**; produce final figures:
# - ROC curve, confusion matrix
# - Feature importance (trees)
# - Learning curve (MLP, optional)
#
# **Ablations:** feature groups (behavioral/temporal/RFM), model families (linear/tree/MLP).
