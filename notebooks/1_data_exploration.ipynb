# %% [markdown]
# # 1) Data Exploration & Preprocessing

# %% [markdown]
# Goals:
# - Load UCI dataset
# - EDA (distributions, imbalance)
# - Leakage audit & train/val/test split
# - Save any processed artifacts if needed

# %% [markdown]
# **To-do:** implement loading via `src/data_loader.py`, preprocessing via `src/preprocessing.py`.
