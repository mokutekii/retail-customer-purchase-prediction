# %% [markdown]
# # 2) Baseline Models

# %% [markdown]
# Train and evaluate:
# - Logistic Regression (baseline)
# - Decision Tree (simple non-linear baseline)
#
# Metrics: ROC-AUC (primary), F1/Precision/Recall, confusion matrix.
