# %% [markdown]
# # 3) Advanced Models

# %% [markdown]
# Train and evaluate:
# - Random Forest (tuned)
# - (Optional) Gradient Boosting
# - Shallow MLP (feedforward)
#
# Compare vs baselines. Track overfitting; use validation for tuning.
